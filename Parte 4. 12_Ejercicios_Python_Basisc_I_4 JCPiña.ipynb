# %% [markdown]
# ## Ejercicio 1
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
lista = [4,6,8,-1]
max (lista)
# Out:
# 8

# %%
sum (lista)
# Out:
# 17

# %%
valor = 63.451256965
float(round(valor,3))
# Out:
# 63.451

# %%
print(type(valor))
# Out:
# <class 'float'>

# %%
valor_abs = -74
abs(valor_abs)
# Out:
# 74

# %% [markdown]
# ## Ejercicio 2
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."
#
# 1. Pásalo todo a mayúsculas
# 2. Pásalo todo a minúsculas
# 3. Solo la primera letra de cada palabra en mayúscula, el resto en minúscula
# 4. Crea una lista dividiéndolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minúsculas

# %%
texto = "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."
texto1 = print(texto.upper())
# Out:
# EN UN LUGAR DE LA MANCHA, DE CUYO NOMBRE NO QUIERO ACORDARME.

# %%
texto2 = print(texto.lower())
# Out:
# en un lugar de la mancha, de cuyo nombre no quiero acordarme.

# %%
texto3 = print(texto.title())
# Out:
# En Un Lugar De La Mancha, De Cuyo Nombre No Quiero Acordarme.

# %%
texto4 = print(texto.split(" "))
# Out:
# ['En', 'un', 'lugar', 'de', 'la', 'Mancha,', 'de', 'cuyo', 'nombre', 'no', 'quiero', 'acordarme.']

# %%
print(texto.replace(",", ";"))
print(texto4.replace(",", ";")) # se podría hacer est cambio? porque me da error?
# Out:
# En un lugar de la Mancha; de cuyo nombre no quiero acordarme.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 print(texto.replace(",", ";"))
# ----> 2 print(texto4.replace(",", ";")) # se podría hacer est cambio? porque me da error?
#
# AttributeError: 'NoneType' object has no attribute 'replace'

# %%
texto6 = print(texto.replace("a", ""))
# Out:
# En un lugr de l Mnch, de cuyo nombre no quiero cordrme.

# %% [markdown]
# ## Ejercicio 3
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.
# 7. Ordena la lista de menor a mayor.
# 8. BONUS: Ordena la lista de mayor a menor.
# (*PISTA: Para hacer 8, tendrás que buscar en la información del método...*)
#
#
# NOTA: Pinta por pantalla el resultado de cada paso.

# %%
list = [4,65,47] #crea una lista de 3 elementos numéricos
print(list)
# Out:
# [4, 65, 47]

# %%
list.append(50) #añado un cuarto elemento
print(list)
# Out:
# [4, 65, 47, 50]

# %%
total = sum(list) #cálculo sumatoria de todos los elementos de la lista
print(total)
# Out:
# 166

# %%
list.pop(1) #elimino posición 2 de la lista , he ejecutado dos veces y se ha eliminado posición 3 también
print(list)
# Out:
# [4, 50]

# %%
list.insert(1,47)
print(list)
# Out:
# [4, 47, 50]

# %%
list.insert(3, 100 #añado valor 100 en última posición pero como uso -1 me lo pone en la posición 2, por lo que modifico y modifico a insertarlo en posición 3 y tampoco me va
print(list)
# Out:
# [4, 47, 100, 100, 50]

# %%
print(list)
# Out:
# [4, 47]

# %%
list.append(50 # elimino segundo elemento de la lista inicial
print(list)
# Out:
# [4, 47, 50]

# %%
list.insert(3, 10) #añado un valor en la posición 3 de la lista
print(list)
# Out:
# [4, 47, 50, 10]

# %%
list2 = ["esto" , "es" , "complicado"] #creación de segunda lista
print(list2)
# Out:
# ['esto', 'es', 'complicado']

# %%
concat = list +list2 #concatenar elementos de dos listas
print(concat)
# Out:
# [4, 47, 50, 10, 'esto', 'es', 'complicado']

# %%
list_ordenada = concat.sort()
print(list_ordenada)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 list_ordenada = concat.sort()
#       2 print(list_ordenada)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
list3 = [5,78,15,23] #rehecho el ejercicio porque debo asignar valores numéricos
print(list3)
# Out:
# [5, 78, 15, 23]

# %%
concat2 = list + list3
print(concat2)
# Out:
# [4, 47, 50, 10, 5, 78, 15, 23]

# %%
concat2.sort() #ordeno la lista de menor a mayor
print(concat2)
# Out:
# [4, 5, 10, 15, 23, 47, 50, 78]

# %%
concat2.reverse() # ordeno la lista de mayor a menor
print(concat2)
# Out:
# [78, 50, 47, 23, 15, 10, 5, 4]
