# %% [markdown]
# ## **EJERCICIO 1**
#
# ## Aptitudes de data science
# **Lo más importante**
# * Matémáticas
# * Pyhton
# * SQL
#
#
#   ![Logo de Python](python.png)
#
#
# Otro tema importante es el *Business Intelligence*
#
# Si tienes dudas, puedes escribirme a: [jcpinamartinez@gmail.com](jcpinamartinez@gmail.com)
#
# Y en esta página se aprende mucho de machine learning: **[página de ML](https://www.kaggle.com)**

# %% [markdown]
# ## **EJERCICIO 2**

# %% [markdown]
# |Ramp up|Data Analysis|Machine Learning|Data & Business|
# |:-|:-|:-|:-|
# |Phyton|EDA|Supervised|Productivización|
# |Estadística|R|Non Supervised|Storytelling|
# |SQL|Feat.Eng.|Deep Learning|API|

# %% [markdown]
# $$ \sqrt{3x-1} + (1+x)^2 $$
